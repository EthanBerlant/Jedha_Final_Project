# %%
import pandas as pd
import numpy as np

# %%
dat = pd.read_csv("stockData.csv")

# %%
dat.describe()
# Out:
#          SPX Index  TSLA US Equity  AAPL US Equity  NKE US Equity  \
# count  1434.000000     1434.000000     1434.000000    1434.000000
# mean   3224.526764      306.741641       82.312997      97.658424
# std     720.211177      339.210243       45.999494      34.732270
# min    2237.400000       35.794000       28.955000      50.830000
# 25%    2682.282500       60.779000       43.558500      68.872500
# 50%    2933.075000       71.474000       56.790000      87.435000
# 75%    3821.500000      642.975000      126.580750     129.707500
# max    4796.560000     1229.910000      182.010000     177.510000
#
#        AMZN US Equity  WMT US Equity  KO US Equity   XAU Curncy   CL1 Comdty  \
# count     1434.000000    1434.000000   1434.000000  1434.000000  1434.000000
# mean       107.387012     112.862092     50.122713  1532.728257    60.157001
# std         43.580422      25.208714      5.905456   265.545802    18.118752
# ...
